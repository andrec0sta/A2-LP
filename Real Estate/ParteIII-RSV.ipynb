# %%
# %run parteRSV.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511 entries, 0 to 510
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     511 non-null    float64
#  1   ZN       511 non-null    float64
#  2   INDUS    511 non-null    float64
#  3   CHAS     511 non-null    bool
#  4   NOX      511 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      511 non-null    float64
#  7   DIS      511 non-null    float64
#  8   RAD      511 non-null    int64
#  9   TAX      511 non-null    int64
#  10  PTRATIO  511 non-null    float64
#  11  B        511 non-null    float64
#  12  LSTAT    511 non-null    float64
#  13  MEDV     511 non-null    float64
# dtypes: bool(1), float64(11), int64(2)
# memory usage: 52.5 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506 entries, 0 to 510
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(x_treino1,y_treino1,color='c')
plt.plot(x_treino1, model1.predict(x_treino1),color='m')
plt.title("NO por Indústrias")
plt.ylabel('Concentração de Oxido Nitrico(PPM)')
plt.xlabel('Proporção de industrias')
plt.savefig("industrias.png")
plt.show()

# %%
plt.scatter(x_treino2,y_treino2,color='c')
plt.plot(x_treino2, model2.predict(x_treino2),color='m')
plt.title("Imposto por Valor")
plt.ylabel('Valor médio das casas')
plt.xlabel('Taxa de imposto sobre a propriedade')
plt.savefig("imposto.png")
plt.show()

# %%
plt.scatter(model3.predict(x_treino3),y_treino3,color='c')
plt.plot([1,50], [1,50],color='m')
plt.title("Previsão por Realidade")
plt.ylabel("Preço real das casas")
plt.xlabel("Preço previsto para as casas")
plt.savefig("precocasas.png")
plt.show()
