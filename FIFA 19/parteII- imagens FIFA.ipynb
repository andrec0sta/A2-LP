# %%
# %run Cientista_FIFA.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Counter                   18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club_Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
q1['pos']=q1.index
plt.bar(x='pos',height='Jersey_Number',data=q1)
plt.title('Posições frequentes do camisa 1')
plt.ylabel("Frequência")
plt.xlabel("Posição")
plt.savefig("camisa1.png")
plt.show()

# %%
plt.scatter(modelg.predict(x_treinog),y_treinog, alpha = .075, color='c')
plt.plot([1,12500], [1,12500],color='r')
plt.title('Realidade por Previsão (Goleiro)')
plt.ylabel('Preço real dos goleiros')
plt.xlabel('Preço previsto para goleiros')
plt.savefig("goleiros.png")
plt.show()
print(modelg.score(x_treinog, y_treinog))
# Out:
# 0.43813365434363527

# %%
plt.scatter(modelt.predict(x_treinot),y_treinot,alpha = .075, color='c')
plt.plot([1,20000], [1,20000], color='r')
plt.title('Realidade por Previsão (Todos)')
plt.ylabel('Preço real de todos os jogadores')
plt.xlabel('Preço previsto para todos os jogadores')
plt.savefig("jogadores.png")
plt.show()
print(modelt.score(x_treinot, y_treinot))
# Out:
# 0.4758152997803413

# %%
plt.scatter(modela.predict(x_treinoa),y_treinoa,alpha = .075, color='c')
plt.plot([1,30000], [1,30000], color='r')
plt.title('Realidade por Previsão (Atacantes)')
plt.ylabel('Preço real dos atacantes')
plt.xlabel('Preço previsto para atacantes')
plt.savefig("Atacantes.png")
plt.show()
print(modela.score(x_treinoa, y_treinoa))
# Out:
# 0.5162631393108521

# %%
plt.scatter(modeld.predict(x_treinod),y_treinod,alpha = .075, color='c')
plt.plot([1,20000], [1,20000], color='r')
plt.title('Realidade por Previsão (Defensores)')
plt.ylabel('Preço real dos defensores')
plt.xlabel('Preço previsto para defensores')
plt.savefig("defensores.png")
plt.show()
print(modeld.score(x_treinod, y_treinod))
# Out:
# 0.5624281066954637

# %%
q2['pos']=q2.index
plt.bar(x='pos',height='Jersey_Number',data=q2)
plt.title("Posições frequentes do camisa 10")
plt.ylabel('Frequência')
plt.xlabel("Posições")
plt.savefig("camisa10.png")
plt.show()

# %%
plt.scatter(modelm.predict(x_treinom),y_treinom,alpha = .075, color='c')
plt.plot([1,20000], [1,20000], color='r')
plt.title('Realidade por Previsão (Meias)')
plt.ylabel('Preço real dos meias')
plt.xlabel('Preço previsto para meias')
plt.savefig("meias.png")
plt.show()
print(modelm.score(x_treinom, y_treinom))
# Out:
# 0.49230642485840737

# %%
q4["pos"] = q4.index
barWidth = 0.15
r1 = np.arange(len(q4.pos))
r2 = [x + barWidth for x in r1]

plt.bar(r1, q4.Overall, width = barWidth, color = 'r', capsize=7, label='Avaliação')
 
plt.bar(r2, q4.Value/36, width = barWidth, color = 'm', capsize=7, label='Preço/40')

plt.xticks([r + barWidth for r in range(len(q4.pos))], q4.pos)
plt.ylabel("Valorização")
plt.xlabel("Posições")
plt.legend()
plt.title("Posições mais valorizadas")
plt.savefig("q4.png")
 
plt.show()

# %%
q3["pos"] = q3.index
barWidth = 0.15
r1 = np.arange(len(q3.pos))
r2 = [x + barWidth for x in r1]

plt.bar(r1, q3.Overall, width = barWidth, color = 'r', capsize=7, label='Avaliação')
 
plt.bar(r2, q3.Value/36, width = barWidth, color = 'm', capsize=7, label='Preço/40')

plt.xticks([r + barWidth for r in range(len(q3.pos))], q3.pos)
plt.ylabel("Valorização")
plt.xlabel("Número da Camisa")
plt.legend()
plt.title("Números mais valorizados")
plt.savefig("q3.png")
 
plt.show()

# %%
q5["pos"] = q5.index
barWidth = 0.15
r1 = np.arange(len(q5.pos))
r2 = [x + barWidth for x in r1]

plt.bar(r1, q5.Overall, width = barWidth, color = 'r', capsize=7, label='Avaliação')
 
plt.bar(r2, q5.Value/36, width = barWidth, color = 'm', capsize=7, label='Preço/40')

plt.xticks([r + barWidth for r in range(len(q5.pos))], q5.pos)
plt.ylabel("Valorização")
plt.xlabel("Idade")
plt.legend()
plt.title("Idade mais valorizada")
plt.savefig("q5.png")
 
plt.show()

# %%
q5g["pos"] = q5g.index
barWidth = 0.15
r1 = np.arange(len(q5g.pos))
r2 = [x + barWidth for x in r1]

plt.bar(r1, q5g.Overall, width = barWidth, color = 'r', capsize=7, label='Avaliação')
 
plt.bar(r2, q5g.Value/36, width = barWidth, color = 'm', capsize=7, label='Preço/40')

plt.xticks([r + barWidth for r in range(len(q5g.pos))], q5g.pos)
plt.ylabel("Valorização")
plt.xlabel("Idade do goleiro")
plt.legend()
plt.title("Idade de goleiro mais valorizada")
plt.savefig("q5g.png")
 
plt.show()
